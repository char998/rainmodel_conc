# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-era5-pressure-levels',
    {
        'product_type': 'reanalysis',
        'variable': [
            'temperature',
            #'dew_point_temperature',
            'geopotential',  # <-- This gives you the heights
            'specific_humidity'
        ],
        'pressure_level': [
            '1000', '975', '950', '925', '900', '875', '850', '825', '800', '775',
            '750', '700', '650', '600', '550', '500', '450', '400', '350', '300',
            '250', '225', '200'
        ],
        'year': '2024',
        'month': '07',
        'day': '31',
        'time': [
    '00:00', '01:00', '02:00', '03:00', '04:00', '05:00',
    '06:00', '07:00', '08:00', '09:00', '10:00', '11:00',
    '12:00', '13:00', '14:00', '15:00', '16:00', '17:00',
    '18:00', '19:00', '20:00', '21:00', '22:00', '23:00',
],
        'format': 'netcdf',
        'area': [54, 3, 50, 8],
    },
    'profiles_era_3107.nc')
# Out:
# 2025-06-13 14:58:39,786 INFO [2025-06-10T00:00:00] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# 2025-06-13 14:58:39,787 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-06-13 14:58:40,120 INFO Request ID is 02df0dc9-4106-4eab-aed2-9bc778b0facb
# 2025-06-13 14:58:40,202 INFO status has been updated to accepted
# 2025-06-13 14:59:02,314 INFO status has been updated to running
# 2025-06-13 15:01:38,069 INFO status has been updated to successful
# 'profiles_era_3107.nc'

# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-era5-pressure-levels',
    {
        'product_type': 'reanalysis',
        'variable': 'temperature',
        'pressure_level': [
            '1000', '975', '950', '925', '900', '875', '850', '825', '800', '775',
            '750', '700', '650', '600', '550', '500', '450', '400', '350', '300',
            '250', '225', '200', '175', '150', '125', '100'
        ],
        'year': '2024',
        'month': '07',
        'day': '31',
        'time': [
    '00:00', '01:00', '02:00', '03:00', '04:00', '05:00',
    '06:00', '07:00', '08:00', '09:00', '10:00', '11:00',
    '12:00', '13:00', '14:00', '15:00', '16:00', '17:00',
    '18:00', '19:00', '20:00', '21:00', '22:00', '23:00',
],
        'format': 'netcdf',  # or 'grib'
        'area': [54, 3, 50, 8],  # North, West, South, East
    },
    'temperature_profiles_more_3107.nc')
# Out:
# 2025-06-13 15:01:39,849 INFO [2025-06-10T00:00:00] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# 2025-06-13 15:01:39,850 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-06-13 15:01:40,098 INFO Request ID is c7469648-d953-47d3-9eb2-879bf22c3079
# 2025-06-13 15:01:40,163 INFO status has been updated to accepted
# 2025-06-13 15:01:54,041 INFO status has been updated to running
# 2025-06-13 15:02:56,098 INFO status has been updated to successful
# 'temperature_profiles_more_3107.nc'

# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'reanalysis-era5-single-levels',
    {
        'product_type': 'reanalysis',
        'variable': ['2m_dewpoint_temperature','2m_temperature', 'surface_pressure'],
        'year': '2024',
        'month': '07',
        'day': '31',
        'time': [
    '00:00', '01:00', '02:00', '03:00', '04:00', '05:00',
    '06:00', '07:00', '08:00', '09:00', '10:00', '11:00',
    '12:00', '13:00', '14:00', '15:00', '16:00', '17:00',
    '18:00', '19:00', '20:00', '21:00', '22:00', '23:00',
],
        'format': 'netcdf',
        'area': [54, 3, 50, 8],
    },
    'surface_era_3107.nc')
# Out:
# 2025-06-13 15:02:57,214 INFO [2025-06-10T00:00:00] To improve our C3S service, we need to hear from you! Please complete this very short [survey](https://confluence.ecmwf.int/x/E7uBEQ/). Thank you.
# 2025-06-13 15:02:57,216 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-06-13 15:02:57,611 INFO Request ID is 4fc82f64-7e96-46c5-9aa7-df8b545c418b
# 2025-06-13 15:02:57,794 INFO status has been updated to accepted
# 2025-06-13 15:03:11,482 INFO status has been updated to running
# 2025-06-13 15:03:30,721 INFO status has been updated to successful
# 'surface_era_3107.nc'
